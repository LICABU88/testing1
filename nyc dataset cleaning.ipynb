# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("nyc-rolling-sales.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
df.columns = ['nameless','BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX_CLASS', 'BLOCK', 'LOT', 'EASE_MENT',
       'BUILDING_CLASS AT PRESENT', 'ADDRESS', 'APT_NUM', 'ZIP_CODE',
       'RESIDENTIAL_UNITS', 'COMMERCIAL_UNITS', 'TOTAL_UNITS',
       'LAND_SQ_FT', 'GROSS_SQ_FT', 'YR_BUILT',
       'TAX_CLASS_TIME_OF_SALE', 'BUILDING_CLASS_TIME_OF_SALE',
       'PRICE', 'SALE_DATE']

# %%
df.head()
# Out:
#    nameless  BOROUGH   NEIGHBORHOOD  \
# 0         4        1  ALPHABET CITY
# 1         5        1  ALPHABET CITY
# 2         6        1  ALPHABET CITY
# 3         7        1  ALPHABET CITY
# 4         8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX_CLASS  BLOCK  LOT  \
# 0  07 RENTALS - WALKUP APARTMENTS                     2A    392    6
# 1  07 RENTALS - WALKUP APARTMENTS                      2    399   26
# 2  07 RENTALS - WALKUP APARTMENTS                      2    399   39
# 3  07 RENTALS - WALKUP APARTMENTS                     2B    402   21
# 4  07 RENTALS - WALKUP APARTMENTS                     2A    404   55
#
#   EASE_MENT BUILDING_CLASS AT PRESENT                 ADDRESS  \
# 0                                  C2            153 AVENUE B
# 1                                  C7   234 EAST 4TH   STREET
# 2                                  C7   197 EAST 3RD   STREET
# 3                                  C4     154 EAST 7TH STREET
# ...

# %%
df['PRICE']=df.PRICE.apply(lambda x: x.replace(' - ', '0')) #use this one

# %%
df['PRICE']=df.PRICE.apply(lambda x: x.strip(' - ')) #do not use; leaving as an example

# %%
pd.value_counts(df['PRICE'])
# Out:
# 0           14561
# 0           10228
# 10            766
# 450000        427
# 550000        416
# 650000        414
# 600000        409
# 700000        382
# 400000        378
# 750000        377
# 300000        351
# 500000        350
# 350000        345
# 800000        331
# 900000        324
# 250000        314
# 850000        309
# 950000        301
# 1100000       298
# 1200000       286
# 1300000       271
# 425000        265
# 475000        259
# 525000        259
# 325000        249
# 480000        233
# 1250000       229
# 625000        224
# 200000        223
# 460000        222
#             ...
# 3740388         1
# 22460           1
# 1422500         1
# 147888          1
# 201820          1
# 4427296         1
# 976500          1
# 250             1
# 163354          1
# 307821          1
# 4985830         1
# 356025          1
# 563750          1
# 1100912         1
# 484275          1
# 16546562        1
# 2183500         1
# 6709375         1
# 662881          1
# ...

# %%
df.dtypes
# Out:
# nameless                        int64
# BOROUGH                         int64
# NEIGHBORHOOD                   object
# BUILDING CLASS CATEGORY        object
# TAX_CLASS                      object
# BLOCK                           int64
# LOT                             int64
# EASE_MENT                      object
# BUILDING_CLASS AT PRESENT      object
# ADDRESS                        object
# APT_NUM                        object
# ZIP_CODE                        int64
# RESIDENTIAL_UNITS               int64
# COMMERCIAL_UNITS                int64
# TOTAL_UNITS                     int64
# LAND_SQ_FT                     object
# GROSS_SQ_FT                    object
# YR_BUILT                        int64
# TAX_CLASS_TIME_OF_SALE          int64
# BUILDING_CLASS_TIME_OF_SALE    object
# PRICE                          object
# SALE_DATE                      object
# dtype: object

# %%
df['PRICE']=df['PRICE'].apply(lambda x: int(x))

# %%
df.dtypes
# Out:
# nameless                        int64
# BOROUGH                         int64
# NEIGHBORHOOD                   object
# BUILDING CLASS CATEGORY        object
# TAX_CLASS                      object
# BLOCK                           int64
# LOT                             int64
# EASE_MENT                      object
# BUILDING_CLASS AT PRESENT      object
# ADDRESS                        object
# APT_NUM                        object
# ZIP_CODE                        int64
# RESIDENTIAL_UNITS               int64
# COMMERCIAL_UNITS                int64
# TOTAL_UNITS                     int64
# LAND_SQ_FT                     object
# GROSS_SQ_FT                    object
# YR_BUILT                        int64
# TAX_CLASS_TIME_OF_SALE          int64
# BUILDING_CLASS_TIME_OF_SALE    object
# PRICE                           int64
# SALE_DATE                      object
# dtype: object

# %%
pd.value_counts(df['PRICE'])
# Out:
# 0           24789
# 10            766
# 450000        427
# 550000        416
# 650000        414
# 600000        409
# 700000        382
# 400000        378
# 750000        377
# 300000        351
# 500000        350
# 350000        345
# 800000        331
# 900000        324
# 250000        314
# 850000        309
# 950000        301
# 1100000       298
# 1200000       286
# 1300000       271
# 425000        265
# 525000        259
# 475000        259
# 325000        249
# 480000        233
# 1250000       229
# 625000        224
# 200000        223
# 460000        222
# 430000        217
#             ...
# 389594          1
# 417768          1
# 1138888         1
# 12251134        1
# 1810448         1
# 546863          1
# 196676          1
# 7463000         1
# 2090823         1
# 964723          1
# 577662          1
# 382785          1
# 9167000         1
# 907423          1
# 712888          1
# 4407500         1
# 1303000         1
# 4170000         1
# 573756          1
# ...

# %%
df=df.drop('nameless', axis=1)

# %%
df.describe()
# Out:
#             BOROUGH         BLOCK           LOT      ZIP_CODE  \
# count  84548.000000  84548.000000  84548.000000  84548.000000
# mean       2.998758   4237.218976    376.224015  10731.991614
# std        1.289790   3568.263407    658.136814   1290.879147
# min        1.000000      1.000000      1.000000      0.000000
# 25%        2.000000   1322.750000     22.000000  10305.000000
# 50%        3.000000   3311.000000     50.000000  11209.000000
# 75%        4.000000   6281.000000   1001.000000  11357.000000
# max        5.000000  16322.000000   9106.000000  11694.000000
#
#        RESIDENTIAL_UNITS  COMMERCIAL_UNITS   TOTAL_UNITS      YR_BUILT  \
# count       84548.000000      84548.000000  84548.000000  84548.000000
# mean            2.025264          0.193559      2.249184   1789.322976
# std            16.721037          8.713183     18.972584    537.344993
# min             0.000000          0.000000      0.000000      0.000000
# ...
